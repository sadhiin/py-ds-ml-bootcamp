# %%
import numpy as np
import pandas as pd

# %%
d = {
    'A':[1,2,np.nan],
    'B':[5,np.nan,np.nan],
    'C':[1,2,3]
}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(thresh=2) #->Require that many non-NA values to execute the dropna function.
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %% [markdown]
# More about dataframe.dropna() [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)

# %%
df.fillna(value="Filled vlaue")
# Out:
#               A             B  C
# 0           1.0           5.0  1
# 1           2.0  Filled vlaue  2
# 2  Filled vlaue  Filled vlaue  3

# %%
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df['A']
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# Name: A, dtype: float64
